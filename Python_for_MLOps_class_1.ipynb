# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitg-ai/ai-agents-for-beginners/blob/main/Python_for_MLOps_class_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = 10
print(x)
# Out:
# 10

# %%
X = 100
print(X)
print(x)
# Out:
# 100
# 10

# %%
_name = "John"
print(_name)
# Out:
# John

# %%
_100 = "welcome"
print(_100)
# Out:
# welcome

# %%
y123 = 500
print(y123)
# Out:
# 500

# %% [markdown]
# # Keywords

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def = 150
print(def)
# Out:
#   File "<ipython-input-6-0230cdb68214>", line 1
#     def = 150
#         ^
# SyntaxError: invalid syntax

# %%
from = 100
# Out:
#   File "<ipython-input-7-422194b066e0>", line 1
#     from = 100
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # In Class Assignment
# - Create a Variable and assign the value as 1000, and print output
# - Classify below variables as Valid/Invalid:
#   - !abc
#   - abc123
#   - _12
#   - abc_12
#   - ab!c
#   - abc123_
#   - 123abc
#   - xyxyxxx
#   - xy1_1
#   - while
#   - for

# %%
for = 100
# Out:
#   File "<ipython-input-16-93a197802c14>", line 1
#     for = 100
#         ^
# SyntaxError: invalid syntax

# %%
# Data Types in Python
# numeric
# boolean
# sequence

# %%
# Numeric data types
# int, float, complex
x = 10
y = -100
print(type(x))
# Out:
# <class 'int'>

# %%
print(type(y))
# Out:
# <class 'int'>

# %%
a = 10.0
b = 1.45
c = -2.456
print(a)
print(type(a))
print(b)
print(type(b))
print(c)
print(type(c))
# Out:
# 10.0
# <class 'float'>
# 1.45
# <class 'float'>
# -2.456
# <class 'float'>

# %%
d = 4.2 + 2j
print(d)
print(type(d))
# Out:
# (4.2+2j)
# <class 'complex'>

# %%
e = True
f = False
print(e)
print(type(e))
print(f)
print(type(f))
# Out:
# True
# <class 'bool'>
# False
# <class 'bool'>

# %%
#Sequences
# Strings
x = "hello" # single line
y = 'welcome' # single line
a = """mlops""" # multi-line
b = '''learning''' # multi-line
print(x)
print(type(x))
print(y)
print(type(y))
print(a)
print(type(a))
print(b)
print(type(b))
# Out:
# hello
# <class 'str'>
# welcome
# <class 'str'>
# mlops
# <class 'str'>
# learning
# <class 'str'>

# %%
# Strings
x = "hello welcome to class" # single line

# %%
y = 'hello welcome
to class'
# Out:
#   File "<ipython-input-26-c744129411bf>", line 1
#     y = 'hello welcome
#         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
a = """hello
welcome
to
class"""
print(a)
# Out:
# hello
# welcome
# to
# class

# %%
#Sequences - Lists
x = [10,20,"hello","welcome",1.23]
print(x)
print(type(x))
# Out:
# [10, 20, 'hello', 'welcome', 1.23]
# <class 'list'>

# %%
# tuples
y = (1,2,3,"hello","welcome")
print(y)
print(type(y))
# Out:
# (1, 2, 3, 'hello', 'welcome')
# <class 'tuple'>

# %% [markdown]
# # Create 3 Variables
# - create 2 variables that contains your name and Designation
# - Create a python list - listing all the technologies you have worked with
# - Create a python tuple - listing all the technologies you have worked with

# %% [markdown]
# # Calculator
# - Get 2 values from user
# - understand what operation to perform
# - print the output

# %%
# input()
x = input("Enter a value")
print(x)
# Out:
# Enter a value100
# 100

# %%
num1 = input("enter the value 1: ")
num2 = input("enter the value 2: ")
result = num1 + num2
print(result)
# Out:
# enter the value 1: 10
# enter the value 2: 20
# 1020

# %%
num1 = input("enter the value 1: ")
num2 = input("enter the value 2: ")
print(type(num1))
print(type(num2))
result = num1 + num2
print(result)
# Out:
# enter the value 1: 10
# enter the value 2: 20
# <class 'str'>
# <class 'str'>
# 1020

# %%
#type casting - Explicit Casting
num1 = input("enter the value 1: ")
num2 = input("enter the value 2: ")
num1 = int(num1)
num2 = int(num2)
print(type(num1))
print(type(num2))
result = num1 + num2
print(result)
# Out:
# enter the value 1: 10
# enter the value 2: 20
# <class 'int'>
# <class 'int'>
# 30

# %%
num1 = int("10")
print(num1)
print(type(num1))
# Out:
# 10
# <class 'int'>

# %%
# if..else

x = 10
y = 20
if (x>y):
  print("x is greater than y")
else:
  print("y is greater than x")
# Out:
# y is greater than x

# %%
x = 120
if (x<100):
  print("x is less than 99")

elif (x>=100 and x<125):
  print("X is between 100 and 124")

elif (x>=125 and x<150):
  print("X is between 125 and 149")

else:
  print("x is greater than 149")
# Out:
# X is between 100 and 124

# %% [markdown]
# # Operators in Python

# %%
# Arithmetic
# logical operators
# Assignment Operators
# Comparision operatons
# identity'
# Membership

# %%
# Arithmetic Operation
x = 10
y = 20
print(x+y) # addition
print(x-y) # 10 -20
print(x*y) # multiplication
print(x/y) # division
print(x%y) # modulus
print(x**y) # Exponentiation
print(x//y) # floor division - get only integer component
# Out:
# 30
# -10
# 200
# 0.5
# 10
# 100000000000000000000
# 0

# %%
print(5**2)
# Out:
# 25

# %%
print(True and True)
# Out:
# True

# %%
print(True and False)
# Out:
# False

# %%
print(not True)
# Out:
# False

# %%
print(not False)
# Out:
# True

# %%
# Comparision Operators
x = 10
y = 20
print(x>y)
print(x<y)
print(x>=y)
print(x<=y)
print(x==y) # equality
print(x!=y) # not equal
# Out:
# False
# True
# False
# True
# False
# True

# %%
print(x == x)
# Out:
# True

# %% [markdown]
# # Steps
# - Get 2 inputs from user (store it in separate variables)
# - Convert both of them to int
# - Get the Choice from user, and store it in a variable
# - Based on user choice perform the operation

# %%
choice = input("""Enter your Choice:
                1. Addition
                2. Subtraction
                3. Multiplication
                4. Division """)
choice = int(choice)
if (choice == 1):
  # addition
  # print(output)
elif (choice ==2):
  #subtraction
  # print(output)
# Out:
#   File "<ipython-input-54-d9aa3fdedb5c>", line 10
#     elif (choice ==2):
#     ^
# IndentationError: expected an indented block after 'if' statement on line 7

# %%
num1 = input("enter the value 1: ")
num2 = input("enter the value 2: ")
num1 = int(num1)
num2 = int(num2)
choice = input("""Enter your Choice:
1. Addition
2. Subtraction
3. Multiplication
4. Division """)
choice = int(choice)
if (choice == 1):
  print(num1+num2)
elif (choice ==2):
  print(num1-num2)
elif (choice ==3):
  print(num1*num2)
elif(choice ==4):
  print(num1/num2)
else:
  print("invalid choice")
# Out:
# enter the value 1: 1
# enter the value 2: 2
# Enter your Choice:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division 1
# 3
